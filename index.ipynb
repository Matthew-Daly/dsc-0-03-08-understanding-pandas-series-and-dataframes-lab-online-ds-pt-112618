# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
df.columns = [x.lower() for x in df.columns]
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#Your code here
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
df = df.reset_index()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
df['Num_Lines'] = df.linename.map(lambda line: len(line))
df.tail(50)
# Out:
#        linename    c/a  unit       scp        station division        date  \
# 197575        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/30/2018
# 197576        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/30/2018
# 197577        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/31/2018
# 197578        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/31/2018
# 197579        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/31/2018
# 197580        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/31/2018
# 197581        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/31/2018
# 197582        R  TRAM2  R469  00-05-00  RIT-ROOSEVELT      RIT  08/31/2018
# 197583        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/25/2018
# 197584        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/25/2018
# 197585        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/25/2018
# 197586        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/25/2018
# 197587        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/25/2018
# 197588        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/25/2018
# 197589        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/26/2018
# 197590        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/26/2018
# 197591        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/26/2018
# 197592        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/26/2018
# 197593        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/26/2018
# 197594        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/26/2018
# 197595        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018
# 197596        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018
# 197597        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018
# 197598        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018
# 197599        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018
# 197600        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018
# 197601        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018
# 197602        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018
# 197603        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018
# 197604        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018
# 197605        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018
# 197606        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018
# 197607        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018
# 197608        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018
# 197609        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018
# 197610        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018
# 197611        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018
# 197612        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018
# 197613        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197614        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197615        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197616        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197617        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197618        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197619        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197620        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197621        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197622        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197623        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197624        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
#
#             time     desc  entries  \
# 197575  17:00:00  REGULAR     2803
# 197576  21:00:00  REGULAR     2803
# 197577  01:00:00  REGULAR     2803
# 197578  05:00:00  REGULAR     2803
# 197579  09:00:00  REGULAR     2803
# 197580  13:00:00  REGULAR     2803
# 197581  17:00:00  REGULAR     2803
# 197582  21:00:00  REGULAR     2803
# 197583  01:00:00  REGULAR     5554
# 197584  05:00:00  REGULAR     5554
# 197585  09:00:00  REGULAR     5554
# 197586  13:00:00  REGULAR     5554
# 197587  17:00:00  REGULAR     5554
# 197588  21:00:00  REGULAR     5554
# 197589  01:00:00  REGULAR     5554
# 197590  05:00:00  REGULAR     5554
# 197591  09:00:00  REGULAR     5554
# 197592  13:00:00  REGULAR     5554
# 197593  17:00:00  REGULAR     5554
# 197594  21:00:00  REGULAR     5554
# 197595  01:00:00  REGULAR     5554
# 197596  05:00:00  REGULAR     5554
# 197597  09:00:00  REGULAR     5554
# 197598  13:00:00  REGULAR     5554
# 197599  17:00:00  REGULAR     5554
# 197600  21:00:00  REGULAR     5554
# 197601  01:00:00  REGULAR     5554
# 197602  05:00:00  REGULAR     5554
# 197603  09:00:00  REGULAR     5554
# 197604  13:00:00  REGULAR     5554
# 197605  17:00:00  REGULAR     5554
# 197606  21:00:00  REGULAR     5554
# 197607  01:00:00  REGULAR     5554
# 197608  05:00:00  REGULAR     5554
# 197609  09:00:00  REGULAR     5554
# 197610  13:00:00  REGULAR     5554
# 197611  17:00:00  REGULAR     5554
# 197612  21:00:00  REGULAR     5554
# 197613  01:00:00  REGULAR     5554
# 197614  05:00:00  REGULAR     5554
# 197615  09:00:00  REGULAR     5554
# 197616  13:00:00  REGULAR     5554
# 197617  17:00:00  REGULAR     5554
# 197618  21:00:00  REGULAR     5554
# 197619  01:00:00  REGULAR     5554
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         exits                                                                 \
# 197575                                                 62
# 197576                                                 62
# 197577                                                 62
# 197578                                                 62
# 197579                                                 62
# 197580                                                 62
# 197581                                                 62
# 197582                                                 62
# 197583                                                348
# 197584                                                348
# 197585                                                348
# 197586                                                348
# 197587                                                348
# 197588                                                348
# 197589                                                348
# 197590                                                348
# 197591                                                348
# 197592                                                348
# 197593                                                348
# 197594                                                348
# 197595                                                348
# 197596                                                348
# 197597                                                348
# 197598                                                348
# 197599                                                348
# 197600                                                348
# 197601                                                348
# 197602                                                348
# 197603                                                348
# 197604                                                348
# 197605                                                348
# 197606                                                348
# 197607                                                348
# 197608                                                348
# 197609                                                348
# 197610                                                348
# 197611                                                348
# 197612                                                348
# 197613                                                348
# 197614                                                348
# 197615                                                348
# 197616                                                348
# 197617                                                348
# 197618                                                348
# 197619                                                348
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
#         Num_Lines
# 197575          1
# 197576          1
# 197577          1
# 197578          1
# 197579          1
# 197580          1
# 197581          1
# 197582          1
# 197583          1
# 197584          1
# 197585          1
# 197586          1
# 197587          1
# 197588          1
# 197589          1
# 197590          1
# 197591          1
# 197592          1
# 197593          1
# 197594          1
# 197595          1
# 197596          1
# 197597          1
# 197598          1
# 197599          1
# 197600          1
# 197601          1
# 197602          1
# 197603          1
# 197604          1
# 197605          1
# 197606          1
# 197607          1
# 197608          1
# 197609          1
# 197610          1
# 197611          1
# 197612          1
# 197613          1
# 197614          1
# 197615          1
# 197616          1
# 197617          1
# 197618          1
# 197619          1
# 197620          1
# 197621          1
# 197622          1
# 197623          1
# 197624          1

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries    exits  Num_Lines
# 0  REGULAR  6736067  2283184          7
# 1  REGULAR  6736087  2283188          7
# 2  REGULAR  6736105  2283229          7
# 3  REGULAR  6736180  2283314          7
# 4  REGULAR  6736349  2283384          7

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df['date'] = pd.to_datetime(df.date)
df['day_of_the_week'] = df.date.dt.dayofweek
days = df.groupby('day_of_the_week').sum()
days.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here
def is_weekend(day):
    if day > 4:
        return True
    else:
        return False

    
df['Is_weekend'] = df.day_of_the_week.map(is_weekend)
weekend = df.groupby('Is_weekend').mean()
weekend[['entries', 'exits']].plot(kind='barh')

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
df = df.drop(['division', 'desc'], axis=1)
df.head()
# Out:
#   linename   c/a  unit       scp station       date      time  entries  \
# 0  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  00:00:00  6736067
# 1  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  04:00:00  6736087
# 2  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  08:00:00  6736105
# 3  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  12:00:00  6736180
# 4  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  16:00:00  6736349
#
#      exits  Num_Lines        day  day_of_the_week  Is_weekend  Is_Weekend
# 0  2283184          7 2018-08-25                5        True        True
# 1  2283188          7 2018-08-25                5        True        True
# 2  2283229          7 2018-08-25                5        True        True
# 3  2283314          7 2018-08-25                5        True        True
# 4  2283384          7 2018-08-25                5        True        True
